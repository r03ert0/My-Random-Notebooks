# %%
# %pylab inline

import numpy as np
import scipy.linalg as lin
import scipy.stats as sst
import pylab
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def rnorm(n,u,s):
    return np.random.standard_normal(n)*s+u

# %%
N=1000;
cause1=rnorm(N,0,1);
cause2=rnorm(N,0,1);
cause3=rnorm(N,0,1);
cause4=rnorm(N,0,1);
cause5=rnorm(N,0,1);
cause6=rnorm(N,0,1);

# %%
pylab.hist(cause1,30);

# %%
pylab.hist(cause2,30);

# %%
pylab.scatter(cause1,cause2,alpha=0.1);

# %%
h2=0.99;

G=(cause1+cause2)/np.sqrt(2);
Phenotype1_MZ_Twin1=np.sqrt(h2)*G+np.sqrt(1-h2)*rnorm(N,0,1);
Phenotype1_MZ_Twin2=np.sqrt(h2)*G+np.sqrt(1-h2)*rnorm(N,0,1);

G1=(cause3+cause4)/np.sqrt(2);
G2=(cause3+cause5)/np.sqrt(2);
Phenotype1_DZ_Twin1=np.sqrt(h2)*G1+np.sqrt(1-h2)*rnorm(N,0,1);
Phenotype1_DZ_Twin2=np.sqrt(h2)*G2+np.sqrt(1-h2)*rnorm(N,0,1);

# %%
pylab.axis('equal');
pylab.scatter(Phenotype1_MZ_Twin1,Phenotype1_MZ_Twin2,alpha=0.1);
pylab.savefig('/Users/roberto/Desktop/MZ_A=.99.pdf');

# %%
pylab.axis('equal');
pylab.scatter(Phenotype1_DZ_Twin1,Phenotype1_DZ_Twin2,alpha=0.1);
pylab.savefig('/Users/roberto/Desktop/DZ_A=.99.pdf');

# %%
rMZ=np.corrcoef(Phenotype1_MZ_Twin1,Phenotype1_MZ_Twin2)[0,1];
rDZ=np.corrcoef(Phenotype1_DZ_Twin1,Phenotype1_DZ_Twin2)[0,1];
print rMZ,rDZ
# Out:
# 0.990564848586 0.52385109755

# %%
Falconer_heritability=2*(rMZ-rDZ);
print Falconer_heritability
# Out:
# 0.933427502071

# %%
A=0.1;
C=0.8;
E=0.1;

G=(cause1+cause2)/np.sqrt(2);
Phenotype1_MZ_Twin1=np.sqrt(A)*G+np.sqrt(C)*cause6+np.sqrt(1-A-C)*rnorm(N,0,1);
Phenotype1_MZ_Twin2=np.sqrt(A)*G+np.sqrt(C)*cause6+np.sqrt(1-A-C)*rnorm(N,0,1);

G1=(cause3+cause4)/np.sqrt(2);
G2=(cause3+cause5)/np.sqrt(2);
Phenotype1_DZ_Twin1=np.sqrt(A)*G1+np.sqrt(C)*cause6+np.sqrt(1-A-C)*rnorm(N,0,1);
Phenotype1_DZ_Twin2=np.sqrt(A)*G2+np.sqrt(C)*cause6+np.sqrt(1-A-C)*rnorm(N,0,1);
pylab.axis('equal');
pylab.scatter(Phenotype1_MZ_Twin1,Phenotype1_MZ_Twin2,alpha=0.1);
pylab.savefig('/Users/roberto/Desktop/MZ_C=.8.pdf');
pylab.axis('equal');
pylab.scatter(Phenotype1_DZ_Twin1,Phenotype1_DZ_Twin2,alpha=0.1);
pylab.savefig('/Users/roberto/Desktop/DZ_C=.8.pdf');
rMZ=np.corrcoef(Phenotype1_MZ_Twin1,Phenotype1_MZ_Twin2)[0,1];
rDZ=np.corrcoef(Phenotype1_DZ_Twin1,Phenotype1_DZ_Twin2)[0,1];
Falconer_A=2*(rMZ-rDZ);
Falconer_C=rMZ-A;
Falconer_E=1-A-C;
print Falconer_A,Falconer_C,Falconer_E;
# Out:
# 0.0961850930706 0.79687664062 0.1

# %%
A=0.8;
C=0.1;
E=0.1;

G=(cause1+cause2)/np.sqrt(2);
Phenotype1_MZ_Twin1=np.sqrt(A)*G+np.sqrt(C)*cause6+np.sqrt(1-A-C)*rnorm(N,0,1);
Phenotype1_MZ_Twin2=np.sqrt(A)*G+np.sqrt(C)*cause6+np.sqrt(1-A-C)*rnorm(N,0,1);

G1=(cause3+cause4)/np.sqrt(2);
G2=(cause3+cause5)/np.sqrt(2);
Phenotype1_DZ_Twin1=np.sqrt(A)*G1+np.sqrt(C)*cause6+np.sqrt(1-A-C)*rnorm(N,0,1);
Phenotype1_DZ_Twin2=np.sqrt(A)*G2+np.sqrt(C)*cause6+np.sqrt(1-A-C)*rnorm(N,0,1);
pylab.axis('equal');
pylab.scatter(Phenotype1_MZ_Twin1,Phenotype1_MZ_Twin2,alpha=0.1);
pylab.savefig('/Users/roberto/Desktop/MZ_A=.8.pdf');
pylab.axis('equal');
pylab.scatter(Phenotype1_DZ_Twin1,Phenotype1_DZ_Twin2,alpha=0.1);
pylab.savefig('/Users/roberto/Desktop/DZ_A=.8.pdf');
rMZ=np.corrcoef(Phenotype1_MZ_Twin1,Phenotype1_MZ_Twin2)[0,1];
rDZ=np.corrcoef(Phenotype1_DZ_Twin1,Phenotype1_DZ_Twin2)[0,1];
Falconer_A=2*(rMZ-rDZ);
Falconer_C=rMZ-A;
Falconer_E=1-A-C;
print Falconer_A,Falconer_C,Falconer_E;
# Out:
# 0.722521163149 0.104608638055 0.1

# %%
A=0.1;
C=0.1;
E=0.8;

G=(cause1+cause2)/np.sqrt(2);
Phenotype1_MZ_Twin1=np.sqrt(A)*G+np.sqrt(C)*cause6+np.sqrt(1-A-C)*rnorm(N,0,1);
Phenotype1_MZ_Twin2=np.sqrt(A)*G+np.sqrt(C)*cause6+np.sqrt(1-A-C)*rnorm(N,0,1);

G1=(cause3+cause4)/np.sqrt(2);
G2=(cause3+cause5)/np.sqrt(2);
Phenotype1_DZ_Twin1=np.sqrt(A)*G1+np.sqrt(C)*cause6+np.sqrt(1-A-C)*rnorm(N,0,1);
Phenotype1_DZ_Twin2=np.sqrt(A)*G2+np.sqrt(C)*cause6+np.sqrt(1-A-C)*rnorm(N,0,1);
pylab.axis('equal');
pylab.scatter(Phenotype1_MZ_Twin1,Phenotype1_MZ_Twin2,alpha=0.1);
pylab.savefig('/Users/roberto/Desktop/MZ_E=.8.pdf');
pylab.axis('equal');
pylab.scatter(Phenotype1_DZ_Twin1,Phenotype1_DZ_Twin2,alpha=0.1);
pylab.savefig('/Users/roberto/Desktop/DZ_E=.8.pdf');
rMZ=np.corrcoef(Phenotype1_MZ_Twin1,Phenotype1_MZ_Twin2)[0,1];
rDZ=np.corrcoef(Phenotype1_DZ_Twin1,Phenotype1_DZ_Twin2)[0,1];
Falconer_A=2*(rMZ-rDZ);
Falconer_C=rMZ-A;
Falconer_E=1-A-C;
print Falconer_A,Falconer_C,Falconer_E;
# Out:
# 0.166008735653 0.138700194921 0.8

# %%
# cause1: causal genetic factors shared by phenotype 1 and 2
# cause2: causal genetic factors exclusive to phenotype 1
G=(cause1+cause3)/np.sqrt(2);
Phenotype1_MZ_Twin1=np.sqrt(h2)*G+np.sqrt(1-h2)*rnorm(N,0,1);
Phenotype1_MZ_Twin2=np.sqrt(h2)*G+np.sqrt(1-h2)*rnorm(N,0,1);

G1=((cause1+cause2)+(cause3+cause4))/np.sqrt(4);
G2=((cause1+cause5)+(cause3+cause6))/np.sqrt(4);
Phenotype1_DZ_Twin1=np.sqrt(h2)*G1+np.sqrt(1-h2)*rnorm(N,0,1);
Phenotype1_DZ_Twin2=np.sqrt(h2)*G2+np.sqrt(1-h2)*rnorm(N,0,1);

G=(cause1+cause2)/np.sqrt(2);
Phenotype2_MZ_Twin1=np.sqrt(h2)*G+np.sqrt(1-h2)*rnorm(N,0,1);
Phenotype2_MZ_Twin2=np.sqrt(h2)*G+np.sqrt(1-h2)*rnorm(N,0,1);

G1=((cause1+cause5)+(cause3+cause6))/np.sqrt(4);
G1=((cause1+cause5)+(cause3+cause6))/np.sqrt(4);
Phenotype2_DZ_Twin1=np.sqrt(h2)*(cause1+cause2+cause5)/(np.sqrt(3))+np.sqrt(1-h2)*rnorm(N,0,1);
Phenotype2_DZ_Twin2=np.sqrt(h2)*(cause1+cause3)/(np.sqrt(2))+np.sqrt(1-h2)*rnorm(N,0,1);

# %%
# LD score regression
N=50000;
M=1e+5;
h2=0.8;
l=1+cause1*0.2;
E=N*h2/M*l+1+cause2*0.1;
Sl=np.sqrt(np.var(l));
SE=np.sqrt(np.var(E));
pylab.axis('equal');
pylab.scatter(l,E,alpha=0.1);
pylab.savefig('/Users/roberto/Desktop/LDSC.pdf');
r=np.corrcoef(E,l)[0,1];
b=r*SE/Sl;
print r,b*M/N;
# Out:
# 0.644982679785 0.824132506462

# %%
# cause1: causal genetic factors shared by phenotype 1 and 2
# cause2: causal genetic factors exclusive to phenotype 1
N=1000;
cause1=rnorm(N,0,1);
cause2=rnorm(N,0,1);
cause3=rnorm(N,0,1);

h2=0.5; # heritability (A=h2, C=0, E=1-A)

alpha=1; # genetic relationship
Ga=alpha*cause1;
Gb=(1-alpha)*cause2;
Gc=(1-alpha)*cause3;
G1=(Ga+Gb)/np.sqrt(np.var(Ga)+np.var(Gb));
G2=(Ga+Gc)/np.sqrt(np.var(Ga)+np.var(Gc));
Phenotype_Sub1=np.sqrt(h2)*G1+np.sqrt(1-h2)*rnorm(N,0,1);
Phenotype_Sub2=np.sqrt(h2)*G2+np.sqrt(1-h2)*rnorm(N,0,1);
r1=np.corrcoef(Phenotype_Sub1,Phenotype_Sub2)[0,1];

alpha=0.5; # genetic relationship
Ga=alpha*cause1;
Gb=(1-alpha)*cause2;
Gc=(1-alpha)*cause3;
G1=(Ga+Gb)/np.sqrt(np.var(Ga)+np.var(Gb));
G2=(Ga+Gc)/np.sqrt(np.var(Ga)+np.var(Gc));
Phenotype_Sub1=np.sqrt(h2)*G1+np.sqrt(1-h2)*rnorm(N,0,1);
Phenotype_Sub2=np.sqrt(h2)*G2+np.sqrt(1-h2)*rnorm(N,0,1);
r2=np.corrcoef(Phenotype_Sub1,Phenotype_Sub2)[0,1];

Falconer_A=2*(r1-r2);
Falconer_C=r1-Falconer_A;
Falconer_E=1-Falconer_A-Falconer_C;
print Falconer_A,Falconer_C,Falconer_E;
# Out:
# 0.451974137547 0.0268836832926 0.52114217916

# %%
numpy.random.rand(5)
# Out:
# array([ 0.06135525,  0.29272165,  0.10046324,  0.5714929 ,  0.37639216])
