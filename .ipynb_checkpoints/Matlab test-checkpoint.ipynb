% %%
a=[2 3 0; 3 0 2; 0 0 3]
% Out:
% a =
%
%      2     3     0
%      3     0     2
%      0     0     3

% %%
a'
% Out:
% ans =
%
%      2     3     0
%      3     0     0
%      0     2     3

% %%
x=[2 4 7 4 3 7 6 4 6 7];
plot(x)
