# %% [markdown]
# # Simple Neuroimaging
# Roberto Toro, Valparaíso, 2016
#
# A series of volume- and surface-based analyses using online data. We will use open data from the ABIDE initiative (Autism Brain Imaging Data Exchange). We will obtain either static data from Amazon, or interactive data from BrainBox.
#
# Information about the demographic and phenotypic variables available can be found here:
#
# http://fcon_1000.projects.nitrc.org/indi/abide/ABIDEII_Data_Legend.pdf
#
# Information about the neuroimaging data available at Amazon's S3 can be found here:
#
# http://preprocessed-connectomes-project.org/abide/download.html

# %% [markdown]
# ## 1. Imports

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import urllib2 as url
import re
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.power as smp
import matplotlib.pyplot as plt
from StringIO import StringIO
import json

# Install seaborn typing `conda install seaborn`
import seaborn as sns

# Install nilearn and nibabel typing `pip install nilearn`
import nibabel as nib
import nilearn
from nilearn import plotting

# %% [markdown]
# ## 2. Regional brain differences between patients with autism and controls (from ABIDE in Amazon)

# %%
print("hola")
# Out:
# hola

# %%
# Import phenotype file from amazon
pheno_url="https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Phenotypic_V1_0b_preprocessed1.csv"
res=url.urlopen(pheno_url)
txt=res.read()
pheno_df=pd.read_csv(StringIO(txt))

# The column FILE_ID contains the code used to index the data at amazon. The 1st row's code is incorrect. Fix it.
pheno_df.loc[0,'FILE_ID']="Pitt_0050002"

# NaN values are indicated as -9999, replace that by a proper NaN value
pheno_df=pheno_df.replace(-9999,np.nan)

# Print data frame
pd.set_option('display.max_columns', None)
pheno_df
# Out:
#       Unnamed: 0  Unnamed: 0.1  SUB_ID     X  subject  SITE_ID  \
# 0              0             1   50002     1    50002     PITT
# 1              1             2   50003     2    50003     PITT
# 2              2             3   50004     3    50004     PITT
# 3              3             4   50005     4    50005     PITT
# 4              4             5   50006     5    50006     PITT
# 5              5             6   50007     6    50007     PITT
# 6              6             7   50008     7    50008     PITT
# 7              7             8   50009     8    50009     PITT
# 8              8             9   50010     9    50010     PITT
# 9              9            10   50011    10    50011     PITT
# 10            10            11   50012    11    50012     PITT
# 11            11            12   50013    12    50013     PITT
# 12            12            13   50014    13    50014     PITT
# 13            13            14   50015    14    50015     PITT
# 14            14            15   50016    15    50016     PITT
# 15            15            16   50017    16    50017     PITT
# 16            16            17   50019    17    50019     PITT
# 17            17            18   50020    18    50020     PITT
# 18            18            19   50022    19    50022     PITT
# 19            19            20   50023    20    50023     PITT
# 20            20            21   50024    21    50024     PITT
# 21            21            22   50025    22    50025     PITT
# 22            22            23   50026    23    50026     PITT
# 23            23            24   50027    24    50027     PITT
# 24            24            25   50028    25    50028     PITT
# 25            25            26   50029    26    50029     PITT
# 26            26            27   50030    27    50030     PITT
# 27            27            28   50031    28    50031     PITT
# 28            28            29   50032    29    50032     PITT
# 29            29            30   50033    30    50033     PITT
# ...          ...           ...     ...   ...      ...      ...
# 1082        1082          1083   51558  1083    51558      SBL
# 1083        1083          1084   51559  1084    51559      SBL
# 1084        1084          1085   51560  1085    51560      SBL
# 1085        1085          1086   51561  1086    51561      SBL
# 1086                 NaN               90.0    NaN    NaN    NaN
# 1087                 NaN               80.0    NaN    NaN    NaN
# 1088                 NaN               90.0    NaN    NaN    NaN
# 1089                 NaN              100.0    NaN    NaN    NaN
# 1090                 NaN               70.0    NaN    NaN    NaN
# 1091                 NaN              100.0    NaN    NaN    NaN
# 1092                 NaN              100.0    NaN    NaN    NaN
# 1093                 NaN              100.0    NaN    NaN    NaN
# 1094                 NaN             -100.0    NaN    NaN    NaN
# 1095                 NaN              -90.0    NaN  101.0  110.0
# 1096                 NaN               60.0    NaN   93.0  110.0
# 1097                   L                NaN    NaN  108.0  120.0
# 1098                 NaN              100.0    NaN  105.0  121.0
# 1099                 NaN              100.0    NaN  100.0  113.0
# 1100                 NaN               80.0    NaN    NaN    NaN
# 1101                 NaN              -40.0    NaN    NaN    NaN
# 1102                 NaN             -100.0  125.0  129.0  113.0
# 1103                 NaN              100.0  110.0    NaN    NaN
# 1104                 NaN               60.0    NaN  117.0  121.0
# 1105                 NaN              100.0  120.0  119.0  116.0
# 1106                 NaN               80.0    NaN  116.0  121.0
# 1107                 NaN              100.0   95.0  105.0   84.0
# 1108                 NaN              100.0    NaN  133.0  135.0
# 1109                 NaN               90.0   96.0   99.0  106.0
# 1110                   R                NaN  118.0    NaN    NaN
# 1111                   R                NaN  110.0    NaN    NaN
#
#      FIQ_TEST_TYPE VIQ_TEST_TYPE PIQ_TEST_TYPE  ADI_R_SOCIAL_TOTAL_A  \
# 0             WASI          WASI          WASI                  16.0
# 1             WASI          WASI          WASI                  27.0
# 2             WASI          WASI          WASI                  19.0
# 3             WASI          WASI          WASI                  23.0
# 4             WASI          WASI          WASI                  13.0
# 5             WASI          WASI          WASI                  21.0
# 6             WASI          WASI          WASI                  24.0
# 7             WASI          WASI          WASI                  20.0
# 8             WASI          WASI          WASI                   NaN
# 9             WASI          WASI          WASI                  24.0
# 10            WASI          WASI          WASI                  21.0
# 11            WASI          WASI          WASI                  17.0
# 12            WASI          WASI          WASI                  22.0
# 13            WASI          WASI          WASI                  12.0
# 14            WASI          WASI          WASI                  22.0
# 15            WASI          WASI          WASI                  22.0
# 16            WASI          WASI          WASI                  20.0
# 17            WASI          WASI          WASI                   NaN
# 18            WASI          WASI          WASI                  23.0
# 19            WASI          WASI          WASI                   NaN
# 20            WASI          WASI          WASI                  19.0
# 21            WASI          WASI          WASI                  26.0
# 22            WASI          WASI          WASI                  22.0
# 23            WASI          WASI          WASI                  20.0
# 24            WASI          WASI          WASI                   NaN
# 25            WASI          WASI          WASI                  26.0
# 26            WASI          WASI          WASI                   NaN
# 27            WASI          WASI          WASI                   NaN
# 28            WASI          WASI          WASI                   NaN
# 29            WASI          WASI          WASI                   NaN
# ...            ...           ...           ...                   ...
# 1082           NaN           NaN           NaN                   NaN
# 1083           NaN           NaN           NaN                   NaN
# 1084           NaN           NaN           NaN                   NaN
# 1085           NaN           NaN           NaN                   NaN
# 1086           NaN           NaN           NaN                   NaN
# 1087           NaN           NaN           NaN                   NaN
# 1101                    NaN              NaN                  NaN
# 1102                    NaN              NaN                  NaN
# 1103                    NaN              NaN                  NaN
# 1104                    8.0              3.0                  1.0
# 1105                    NaN              NaN                  NaN
# 1106                    9.0              5.0                  3.0
# 1107                    NaN              NaN                  NaN
# 1108                    9.0              3.0                  0.0
# 1109                    NaN              NaN                  NaN
# 1110                    NaN              NaN                  NaN
# 1111                    NaN              NaN                  NaN
#
#       ADI_R_RSRCH_RELIABLE  ADOS_MODULE  ADOS_TOTAL  ADOS_COMM  ADOS_SOCIAL  \
# 0                      1.0          4.0        12.0        4.0          8.0
# 1                      1.0          4.0        13.0        5.0          8.0
# 2                      1.0          4.0        18.0        6.0         12.0
# 3                      1.0          4.0        12.0        4.0          8.0
# 4                      1.0          4.0        12.0        4.0          8.0
# 5                      1.0          3.0        17.0        5.0         12.0
# 6                      1.0          NaN        16.0        4.0         12.0
# 7                      1.0          NaN        10.0        4.0          6.0
# 8                      1.0          NaN         NaN        NaN          NaN
# 9                      1.0          NaN        13.0        4.0          9.0
# 10                     1.0          4.0        12.0        4.0          8.0
# 11                     1.0          3.0        12.0        4.0          8.0
# 12                     1.0          3.0        16.0        5.0         11.0
# 13                     1.0          NaN        19.0        7.0         12.0
# 14                     1.0          4.0        10.0        4.0          6.0
# 15                     1.0          4.0        17.0        5.0         12.0
# 16                     1.0          4.0        13.0        4.0          9.0
# 17                     1.0          NaN         NaN        NaN          NaN
# 18                     1.0          4.0        12.0        4.0          8.0
# 19                     1.0          NaN         NaN        NaN          NaN
# 20                     1.0          4.0        11.0        5.0          6.0
# 21                     1.0          4.0         8.0        3.0          5.0
# 22                     1.0          3.0        13.0        5.0          8.0
# 23                     1.0          3.0        11.0        2.0          9.0
# 24                     1.0          NaN         NaN        NaN          NaN
# 25                     1.0          3.0        13.0        5.0          8.0
# 26                     NaN          NaN         NaN        NaN          NaN
# 27                     NaN          NaN         NaN        NaN          NaN
# 28                     NaN          NaN         NaN        NaN          NaN
# 29                     NaN          NaN         NaN        NaN          NaN
# ...                    ...          ...         ...        ...          ...
# 1082                   NaN          NaN         NaN        NaN          NaN
# 1083                   NaN          NaN         NaN        NaN          NaN
# 1084                   NaN          NaN         NaN        NaN          NaN
# 1085                   NaN          NaN         NaN        NaN          NaN
# 1086                   NaN          NaN         NaN        NaN          NaN
# 1087                   NaN          NaN         NaN        NaN          NaN
# 1088                   NaN          NaN         NaN        NaN          NaN
# 1089                   NaN          NaN         NaN        NaN          NaN
# 1090                   NaN          NaN         NaN        NaN          NaN
# 1091                   NaN          NaN         NaN        NaN          NaN
# 1092                   NaN          NaN         NaN        NaN          NaN
# 1093                   NaN          NaN         NaN        NaN          NaN
# 1094                   NaN          NaN         NaN        NaN          NaN
# 1095                   0.0          4.0         8.0        4.0          4.0
# 1096                   0.0          4.0         7.0        2.0          5.0
# 1097                   0.0          4.0         8.0        3.0          5.0
# 1098                   0.0          4.0        11.0        5.0          6.0
# 1099                   0.0          4.0        10.0        3.0          7.0
# 1100                   NaN          NaN         NaN        NaN          NaN
# 15               NaN             NaN        NaN       NaN               NaN
# 16               NaN             NaN        NaN       NaN               NaN
# 17               NaN             NaN        NaN       NaN               NaN
# 18               NaN             NaN        NaN       NaN               NaN
# 19               NaN             NaN        NaN       NaN               NaN
# 20               NaN             NaN        NaN       NaN               NaN
# 21               NaN             NaN        NaN       NaN               NaN
# 22               NaN             NaN        NaN       NaN               NaN
# 23               NaN             NaN        NaN       NaN               NaN
# 24               NaN             NaN        NaN       NaN               NaN
# 25               NaN             NaN        NaN       NaN               NaN
# 26               NaN             NaN        NaN       NaN               NaN
# 27               NaN             NaN        NaN       NaN               NaN
# 28               NaN             NaN        NaN       NaN               NaN
# 29               NaN             NaN        NaN       NaN               NaN
# ...              ...             ...        ...       ...               ...
# 1082             NaN             NaN        NaN       7.0               NaN
# 1083             NaN             NaN        NaN      14.0               NaN
# 1084             NaN             NaN        NaN      11.0               NaN
# 1085             NaN             NaN        NaN      12.0               NaN
# 1086             NaN             NaN        NaN      17.0               NaN
# 1087             NaN             NaN        NaN      24.0               NaN
# 1088             NaN             NaN        NaN      20.0               NaN
# 1089             NaN             NaN        NaN       NaN               NaN
# 1090             NaN             NaN        NaN      17.0               NaN
# 1091             NaN             NaN        NaN      12.0               NaN
# 1092             NaN             NaN        NaN      15.0               NaN
# 1093             NaN             NaN        NaN      11.0               NaN
# 1094             NaN             NaN        NaN       9.0               NaN
# 1095             NaN             NaN        NaN      33.0              None
# 1096             NaN             NaN        NaN      28.0              None
# 1097             NaN             NaN        NaN       NaN             -9999
# 1098             NaN             NaN        NaN      26.0              None
# 1099             NaN             NaN        NaN      36.0              None
# 1100             NaN             NaN        NaN      42.0              None
# 1101             NaN             NaN        NaN      20.0  ADHD Inattentive
# 1102             NaN             NaN        NaN      36.0              None
# 1103             NaN             NaN        NaN      15.0              None
# 1104             NaN             NaN        NaN      39.0              None
# 1105             NaN             NaN        NaN      24.0              None
# 1106             NaN             NaN        NaN      31.0              None
# 1107             NaN             NaN        NaN      41.0              None
# 1108             NaN             NaN        NaN      39.0              None
# 1109             NaN             NaN        NaN      25.0              None
# 1110             NaN             NaN        NaN       NaN               NaN
# 1111             NaN             NaN        NaN       NaN               NaN
#
#      CURRENT_MED_STATUS                                    MEDICATION_NAME  \
# 0                     0                                                NaN
# 1                     1                                         Fluoxetine
# 2                     0                                                NaN
# 3                     1                                         Fluoxetine
# 4                     0                                                NaN
# 5                     0                                                NaN
# 6                     1                                         Sertraline
# 7                     1                                       Pantoprazole
# 8                     0                                                NaN
# 9                     0                                                NaN
# 10                    0                                                NaN
# 11                    0                                                NaN
# 12                    1                                        Atomoxetine
# 13                    0                                                NaN
# 14                    0                                                NaN
# 15                    0                                                NaN
# 16                    1                        Methylphenidate; Citalopram
# 17                    1                                   Lisdexamfetamine
# 18                    0                                                NaN
# 19                    0                                                NaN
# 20                    0                                                NaN
# 21                    0                                                NaN
# 22                    1  Sertraline; Risperidone; Dextroamphetamine and...
# 23                    0                                                NaN
# 24                    0                                                NaN
# 25                    0                                                NaN
# 26                    0                                                NaN
# 27                    0                                                NaN
# 28                    0                                                NaN
# 29                    0                                                NaN
# ...                 ...                                                ...
# 1082                  0                                                NaN
# 1083                  0                                                NaN
# 1084                  0                                                NaN
# 1085                  0                                                NaN
# 1086                  0                                                NaN
# 1087                  0                                                NaN
# 1088                  0                                                NaN
# 1089                  0                                                NaN
# 1090                  0                                                NaN
# 1091                  0                                                NaN
# ...
# 1102      0.000840      0.005729      0.147765         49.0     24.378109
# 1103      0.002311      0.008146      0.096582         12.0      5.970149
# 1104      0.001758      0.005715      0.160136         62.0     30.845771
# 1105      0.001441      0.013147      0.164442         54.0     26.865672
# 1106      0.001749      0.007724      0.171107         68.0     33.830846
# 1107      0.001204      0.006403      0.116186         24.0     11.940299
# 1108      0.001508      0.012669      0.140171         37.0     18.407960
# 1109      0.002469      0.008923      0.154887         52.0     25.870647
# 1110      0.000784      0.005814      0.048246          0.0      0.000000
# 1111      0.001172      0.007255      0.168913         44.0     36.363636
#
#       func_gsr qc_rater_1 qc_notes_rater_1 qc_anat_rater_2  \
# 0     0.054346       fail              NaN              OK
# 1     0.041862         OK              NaN              OK
# 2     0.046745         OK              NaN              OK
# 3     0.027963         OK              NaN              OK
# 4     0.054006         OK              NaN              OK
# 5     0.055615         OK              NaN              OK
# 6     0.056363         OK              NaN              OK
# 7     0.053051         OK              NaN              OK
# 8     0.036569         OK              NaN              OK
# 9     0.050781         OK              NaN              OK
# 10    0.050571         OK              NaN              OK
# 11    0.033976         OK              NaN              OK
# 12    0.037690         OK              NaN              OK
# 13    0.045516         OK              NaN              OK
# 14    0.057221         OK              NaN              OK
# 15    0.053618         OK              NaN           maybe
# 16    0.066776         OK              NaN              OK
# 17    0.068259         OK              NaN              OK
# 18    0.056679         OK              NaN              OK
# 19    0.041551         OK              NaN              OK
# 20    0.058764         OK              NaN              OK
# 21    0.051174         OK              NaN              OK
# 22    0.057138         OK              NaN              OK
# 23    0.033487         OK              NaN              OK
# 24    0.045800         OK              NaN           maybe
# 25    0.039851         OK              NaN           maybe
# 26    0.049201         OK              NaN              OK
# 27    0.048052         OK              NaN              OK
# 28    0.066515         OK              NaN              OK
# 29    0.035733         OK              NaN              OK
# ...        ...        ...              ...             ...
# 1082  0.019955         OK              NaN              OK
# 1083  0.030739         OK              NaN              OK
# 1084  0.026808         OK              NaN              OK
# 1085  0.034365         OK              NaN              OK
# 1086  0.020315         OK              NaN              OK
# 1087  0.029264         OK              NaN              OK
# 1088  0.037427         OK              NaN              OK
# 1089  0.025146         OK              NaN              OK
# 1090  0.021309         OK              NaN              OK
# 1091  0.035488         OK              NaN              OK
# 1092  0.017776         OK              NaN              OK
# 1093  0.025558         OK              NaN              OK
# 1094  0.022805         OK              NaN              OK
# 1095  0.041192         OK              NaN              OK
# 1096  0.038234         OK              NaN              OK
# 1097  0.030054         OK              NaN              OK
# 1098  0.020495         OK              NaN              OK
# 1099  0.034672         OK              NaN              OK
# 1100  0.022641         OK              NaN              OK
# 1101  0.030638         OK              NaN              OK
# 1102  0.036865         OK              NaN              OK
# 1103  0.025088         OK              NaN              OK
# 1104  0.036961         OK              NaN              OK
# 1105  0.024502         OK              NaN              OK
# 1106  0.042990         OK              NaN              OK
# 1107  0.037362         OK              NaN              OK
# 1108  0.033177         OK              NaN              OK
# 1109  0.026048         OK              NaN              OK
# 1110  0.053727         OK              NaN              OK
# 1111  0.075114         OK              NaN              OK
#
#      qc_anat_notes_rater_2 qc_func_rater_2            qc_func_notes_rater_2  \
# 0                      NaN            fail           ic-parietal-cerebellum
# 1                      NaN              OK                              NaN
# 2                      NaN              OK                              NaN
# 3                      NaN           maybe           ic-parietal-cerebellum
# 4                      NaN           maybe               ic-parietal slight
# 5                      NaN           maybe       ic-cerebellum_temporal_lob
# 6                      NaN              OK                              NaN
# 7                      NaN            fail           ic-parietal-cerebellum
# 8                      NaN           maybe       ic-cerebellum_temporal_lob
# 9                      NaN           maybe       ic-cerebellum_temporal_lob
# 10                     NaN              OK                              NaN
# 11                     NaN              OK                              NaN
# 12                     NaN              OK                              NaN
# 13                     NaN              OK                              NaN
# 14                     NaN           maybe  ic-parietal-cerebellum_temporal
# 15     skull-striping fail           maybe       ic-cerebellum_temporal_lob
# 16                     NaN            fail            ic-occipital_parietal
# 17                     NaN              OK                              NaN
# 18                     NaN           maybe       ic-cerebellum_temporal_lob
# 19                     NaN           maybe      ic-cerebellum_temporal_lobe
# 20                     NaN           maybe       ic-cerebellum_temporal_lob
# 21                     NaN           maybe       ic-cerebellum_temporal_lob
# 22                     NaN           maybe       ic-cerebellum_temporal_lob
# 23                     NaN              OK                    ic-cerebellum
# 24     skull-striping fail           maybe           ic-parietal-cerebellum
# 25     skull-striping fail            fail           ic-parietal-cerebellum
# 26                     NaN           maybe           ic-parietal-cerebellum
# 27                     NaN           maybe      ic-cerebellum_temporal_lobe
# 28                     NaN           maybe      ic-cerebellum_temporal_lobe
# 29                     NaN           maybe      ic-cerebellum_temporal_lobe
# ...                    ...             ...                              ...
# 1082                   NaN           maybe      ic-cerebellum_temporal_lobe
# 1083                   NaN           maybe                    ic-cerebellum
# 1084                   NaN           maybe                    ic-cerebellum
# 1085                   NaN            fail           ic-parietal-cerebellum
# 1086                   NaN           maybe      ic-cerebellum_temporal_lobe
# 1087                   NaN           maybe      ic-cerebellum_temporal_lobe
# 1088                   NaN           maybe      ic-cerebellum-temporal_lobe
# 1089                   NaN           maybe      ic-cerebellum_temporal_lobe
# 1090                   NaN           maybe      ic-cerebellum-temporal_lobe
# 1091                   NaN           maybe      ic-cerebellum-temporal_lobe
# 1092                   NaN           maybe      ic-cerebellum-temporal_lobe
# 1093                   NaN           maybe      ic-cerebellum-temporal_lobe
# 1094                   NaN           maybe      ic-cerebellum-temporal_lobe
# 1095                   NaN            fail           ic-parietal-cerebellum
# 1096                   NaN           maybe      ic-cerebellum-temporal_lobe
# 1097                   NaN           maybe                    ic-cerebellum
# 1098                   NaN           maybe           ic-parietal-cerebellum
# 1099                   NaN            fail      ic-cerebellum-temporal_lobe
# 1100                   NaN           maybe                    ic-cerebellum
# 1101                   NaN           maybe      ic-cerebellum-temporal_lobe
# 1102                   NaN           maybe      ic-cerebellum-temporal_lobe
# 1103                   NaN           maybe      ic-cerebellum-temporal_lobe
# 1104                   NaN           maybe      ic-cerebellum-temporal_lobe
# 1105                   NaN            fail           ic-parietal-cerebellum
# 1106                   NaN           maybe                    ic-cerebellum
# 1107                   NaN              OK      ic-cerebellum-temporal_lobe
# 1108                   NaN           maybe                    vmpfc dropout
# 1109                   NaN           maybe      ic-cerebellum-temporal_lobe
# 1110                   NaN           maybe                    ic-cerebellum
# 1111                   NaN           maybe                    ic-cerebellum
#
#      qc_anat_rater_3 qc_anat_notes_rater_3 qc_func_rater_3  \
# 0                 OK                   NaN            fail
# 1                 OK                   NaN              OK
# 2                 OK                   NaN              OK
# 3                 OK                   NaN              OK
# 4                 OK                   NaN              OK
# 5                 OK                   NaN              OK
# 6                 OK                   NaN              OK
# 7                 OK                   NaN              OK
# 8                 OK                   NaN              OK
# 9                 OK                   NaN              OK
# 10                OK                   NaN              OK
# 11                OK                   NaN              OK
# 12                OK                   NaN              OK
# 13                OK                   NaN              OK
# 14                OK                   NaN              OK
# 15              fail                 noise              OK
# 16                OK                   NaN              OK
# 17                OK                   NaN              OK
# 18                OK                   NaN              OK
# 19                OK                   NaN              OK
# 20                OK                   NaN              OK
# 21                OK                   NaN              OK
# 22                OK                   NaN              OK
# 23                OK                   NaN              OK
# 24                OK                   NaN              OK
# 25                OK                   NaN              OK
# 26                OK                   NaN              OK
# 27                OK                   NaN              OK
# 28                OK                   NaN              OK
# 29                OK                   NaN              OK
# ...              ...                   ...             ...
# 1082              OK                   NaN              OK
# 1083              OK                   NaN              OK
# 1084              OK                   NaN              OK
# 1085              OK                   NaN              OK
# 1086              OK                   NaN              OK
# 1087              OK                   NaN              OK
# 1088              OK                   NaN              OK
# 1089              OK                   NaN              OK
# 1090              OK                   NaN              OK
# 1091              OK                   NaN              OK
# 1092              OK                   NaN              OK
# 1093              OK                   NaN              OK
# 1094              OK                   NaN              OK
# 1095              OK                   NaN              OK
# 1096              OK                   NaN              OK
# 1097              OK                   NaN              OK
# 1098              OK                   NaN              OK
# 1099              OK                   NaN              OK
# 1100              OK                   NaN              OK
# 1101              OK                   NaN              OK
# 1102              OK                   NaN              OK
# 1103              OK                   NaN              OK
# 1104              OK                   NaN              OK
# 1105              OK                   NaN              OK
# 1106              OK                   NaN              OK
# 1107              OK                   NaN              OK
# 1108              OK                   NaN              OK
# 1109              OK                   NaN              OK
# 1110              OK                   NaN              OK
# 1111              OK                   NaN              OK
#
#      qc_func_notes_rater_3  SUB_IN_SMP
# 0                ERROR #24           1
# 1                      NaN           1
# 2                      NaN           1
# 3                      NaN           0
# 4                      NaN           1
# 5                      NaN           1
# 6                      NaN           1
# 7                      NaN           1
# 8                      NaN           1
# 9                      NaN           0
# 10                     NaN           1
# 11                     NaN           1
# 12                     NaN           1
# 13                     NaN           1
# 14                     NaN           1
# 15                     NaN           1
# 16                     NaN           1
# 17                     NaN           1
# 18                     NaN           1
# 19                     NaN           0
# 20                     NaN           1
# 21                     NaN           1
# 22                     NaN           1
# 23                     NaN           1
# 24                     NaN           1
# 25                     NaN           0
# 26                     NaN           1
# 27                     NaN           1
# 28                     NaN           1
# 29                     NaN           1
# ...                    ...         ...
# 1082                   NaN           0
# 1083                   NaN           0
# 1084                   NaN           0
# 1085                   NaN           0
# 1086                   NaN           0
# 1087                   NaN           0
# 1088                   NaN           0
# 1089                   NaN           0
# 1090                   NaN           0
# 1091                   NaN           0
# 1092                   NaN           0
# 1093                   NaN           0
# 1094                   NaN           0
# 1095                   NaN           0
# 1096                   NaN           0
# 1097                   NaN           0
# 1098                   NaN           0
# 1099                   NaN           0
# 1100                   NaN           0
# 1101                   NaN           0
# 1102                   NaN           0
# 1103                   NaN           0
# 1104                   NaN           0
# 1105                   NaN           0
# 1106                   NaN           0
# 1107                   NaN           0
# 1108                   NaN           0
# 1109                   NaN           0
# 1110                   NaN           0
# 1111                   NaN           1
#
# [1112 rows x 106 columns]

# %%
# Plot a few measurements
pheno_df.plot(y='AGE_AT_SCAN',kind='hist')
pheno_df.plot(y='FIQ',kind='hist')

# %% [markdown]
# ## 3. Basic statistical power computations

# %%
# ABIDE 1 included 1102 subjects. Load the first N for testing
N=50

# Statistical power calculations
# (more info at http://jpktd.blogspot.cl/2013/03/statistical-power-in-statsmodels.html)

# Given our sample size N, what is our power to detect small, medium and large effects
d_small = 0.25
d_medium = 0.5
d_large = 1
print "Power for standard effect sizes:"
print smp.TTestIndPower().solve_power(d_small, nobs1=N/2, ratio=1, alpha=0.05, alternative='two-sided')
print smp.TTestIndPower().solve_power(d_medium, nobs1=N/2, ratio=1, alpha=0.05, alternative='two-sided')
print smp.TTestIndPower().solve_power(d_large, nobs1=N/2, ratio=1, alpha=0.05, alternative='two-sided')

# What number of subjects would we need to detect a give effect size with 80% power?
d=0.5
print "Minimum number of subjects per group required to detect an effect size of "+str(d)+" with 80% power:"
print smp.TTestIndPower().solve_power(d, power=0.8, ratio=1, alpha=0.05, alternative='two-sided')
# Out:
# Power for standard effect sizes:
# 0.139404465581
# 0.41010033258
# 0.933707643674
# Minimum number of subjects per group required to detect an effect size of 0.5 with 80% power:
# 63.7656117754

# %% [markdown]
# ## 4. Load regional brain volume measurements for a subset of individuals

# %%
# Load summary data for measurements of subcortical structures

base_url="https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/"
filename="/stats/aseg.stats"

sub_df=[];
for i in range(0,N):
    aseg_url=base_url+pheno_df.FILE_ID[i]+filename
    print(str(i)+". "+aseg_url)
    res=url.urlopen(aseg_url)
    txt=res.read()
    txt=txt.split("\n")[68:113];
    txt="\n".join(txt);
    sub_df.append(pd.read_csv(StringIO(txt),sep='\s+',header=None))
# Out:
# 0. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050002/stats/aseg.stats
# 1. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050003/stats/aseg.stats
# 2. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050004/stats/aseg.stats
# 3. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050005/stats/aseg.stats
# 4. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050006/stats/aseg.stats
# 5. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050007/stats/aseg.stats
# 6. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050008/stats/aseg.stats
# 7. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050009/stats/aseg.stats
# 8. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050010/stats/aseg.stats
# 9. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050011/stats/aseg.stats
# 10. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050012/stats/aseg.stats
# 11. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050013/stats/aseg.stats
# 12. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050014/stats/aseg.stats
# 13. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050015/stats/aseg.stats
# 14. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050016/stats/aseg.stats
# 15. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050017/stats/aseg.stats
# 16. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050019/stats/aseg.stats
# 17. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050020/stats/aseg.stats
# 18. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050022/stats/aseg.stats
# 19. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050023/stats/aseg.stats
# 20. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050024/stats/aseg.stats
# 21. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050025/stats/aseg.stats
# 22. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050026/stats/aseg.stats
# 23. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050027/stats/aseg.stats
# 24. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050028/stats/aseg.stats
# 25. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050029/stats/aseg.stats
# 26. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050030/stats/aseg.stats
# 27. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050031/stats/aseg.stats
# 28. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050032/stats/aseg.stats
# 29. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050033/stats/aseg.stats
# 30. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050034/stats/aseg.stats
# 31. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050035/stats/aseg.stats
# 32. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050036/stats/aseg.stats
# 33. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050037/stats/aseg.stats
# 34. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050038/stats/aseg.stats
# 35. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050039/stats/aseg.stats
# 36. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050040/stats/aseg.stats
# 37. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050041/stats/aseg.stats
# 38. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050042/stats/aseg.stats
# 39. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050043/stats/aseg.stats
# 40. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050044/stats/aseg.stats
# 41. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050045/stats/aseg.stats
# 42. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050046/stats/aseg.stats
# 43. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050047/stats/aseg.stats
# 44. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050048/stats/aseg.stats
# 45. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/freesurfer/5.1/Pitt_0050049/stats/aseg.stats
# 46. https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs
# 36  37   80     29     29.0         non-WM-hypointensities   56.8333  17.4151
# 37  38   81      0      0.0    Left-non-WM-hypointensities    0.0000   0.0000
# 38  39   82      0      0.0   Right-non-WM-hypointensities    0.0000   0.0000
# 39  40   85    322    322.0                   Optic-Chiasm   74.0369  18.0849
# 40  41  251    962    962.0                   CC_Posterior  111.2374   8.2024
# 41  42  252    519    519.0               CC_Mid_Posterior  105.4132  10.5049
# 42  43  253    478    478.0                     CC_Central  106.0241   9.0277
# 43  44  254    444    444.0                CC_Mid_Anterior  107.0625   8.1164
# 44  45  255    995    995.0                    CC_Anterior  106.4155   9.8396
#
#        7      8     9
# 0    0.0   77.0  77.0
# 1   26.0   70.0  44.0
# 2   36.0  105.0  69.0
# 3   15.0   98.0  83.0
# 4   46.0  107.0  61.0
# 5   38.0  103.0  65.0
# 6   62.0  104.0  42.0
# 7   81.0  112.0  31.0
# 8    0.0   69.0  69.0
# 9    0.0   56.0  56.0
# 10  36.0  112.0  76.0
# 11  34.0  105.0  71.0
# 12  34.0   88.0  54.0
# 13   0.0   70.0  70.0
# 14  43.0   92.0  49.0
# 15  43.0  113.0  70.0
# 16  60.0   88.0  28.0
# 17  14.0   94.0  80.0
# 18   0.0   78.0  78.0
# 19  13.0   72.0  59.0
# 20  40.0  101.0  61.0
# 21  11.0   88.0  77.0
# 22  41.0  107.0  66.0
# 23  25.0  100.0  75.0
# 24  55.0  106.0  51.0
# 25  52.0  109.0  57.0
# 26  37.0   95.0  58.0
# 27  48.0   88.0  40.0
# 28  44.0  109.0  65.0
# 29  46.0  111.0  65.0
# 30  39.0   85.0  46.0
# 31  12.0   95.0  83.0
# 32  24.0   60.0  36.0
# 33  28.0  114.0  86.0
# 34   0.0    0.0   0.0
# 35   0.0    0.0   0.0
# 36  29.0   99.0  70.0
# 37   0.0    0.0   0.0
# 38   0.0    0.0   0.0
# 39  27.0  105.0  78.0
# 40  71.0  119.0  48.0
# 41  38.0  117.0  79.0
# 42  56.0  116.0  60.0
# 43  78.0  116.0  38.0
# 44  53.0  123.0  70.0

# %% [markdown]
# ## 5. Statistical analyses

# %% [markdown]
# ### 5.1 Collect the data of interest
#
# We will do our analyses using as covariates the Age at scan and the Diagnosis group. In the following code we will look at the volume of the Hippocampus (left and right hemispheres added). Looking at the first subject's data frame, we see that Left-Hippocampus is row 11 and Right-Hippocampus is row 26. The column containing the volume (in mm3) is the 5th one.

# %%
# We will collect all the information in a new data frame containing all
# the information we need.

# Extract AGE_AT_SCAN from the phenotype data frame pheno_dt
age=pheno_df.AGE_AT_SCAN[0:N]

# Extract the Diagnosis (1=Autism, 2=Control)
group=pheno_df.DX_GROUP[0:N]

# Extract the Right and Left Hippocampus rows from each individual's data frame.
# Volume in mm3 is the 4th column (index = 3)
h=np.empty(N)
for i in range(0,N):
    lh=sub_df[i].loc[11,3]
    rh=sub_df[i].loc[26,3]
    h[i]=lh+rh

# Create a data frame for all our statistical tests
test_df=pd.DataFrame({'A':age, 'G':group, 'H':h});

# Display number of patients and controls
print "Patients: "+str((group==1).sum())
print "Controls: "+str((group==2).sum())
# Out:
# Patients: 27
# Controls: 23

# %% [markdown]
# ### 5.2 Volume difference in patients vs controls

# %%
# 1. Difference in Hippocampal volume between patients and controls

# Plot the difference between groups
sns.stripplot(x='G', y='H', data=test_df, jitter=True)
#sns.swarmplot(x='G', y='H', data=test_df)

# Statistical test: H is different depending on G
res=smf.ols(formula="H ~ C(G)",data=test_df).fit();
# print(res.f_pvalue);
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      H   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.021
# Method:                 Least Squares   F-statistic:                  0.007778
# Date:                Wed, 07 Dec 2016   Prob (F-statistic):              0.930
# Time:                        16:59:15   Log-Likelihood:                -411.18
# No. Observations:                  50   AIC:                             826.4
# Df Residuals:                      48   BIC:                             830.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   8835.4815    177.190     49.864      0.000      8479.217  9191.746
# C(G)[T.2]     23.0403    261.252      0.088      0.930      -502.242   548.323
# ==============================================================================
# Omnibus:                        0.265   Durbin-Watson:                   2.496
# Prob(Omnibus):                  0.876   Jarque-Bera (JB):                0.233
# Skew:                          -0.151   Prob(JB):                        0.890
# Kurtosis:                       2.857   Cond. No.                         2.53
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### 5.3 Change in volume with age

# %%
# 1. Change in Hippocampal volume with Age
# (Our null hypothesis is that there is no change)

# Plot a scatter plot with Hippocampal volume vs. Age
test_df.plot(x='A',y='H',kind='scatter')

# Statistical test: H changes with A
res=smf.ols(formula="H ~ A",data=test_df).fit();
# print(res.f_pvalue);
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      H   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.3571
# Date:                Mon, 05 Dec 2016   Prob (F-statistic):              0.553
# Time:                        09:27:58   Log-Likelihood:                -411.00
# No. Observations:                  50   AIC:                             826.0
# Df Residuals:                      48   BIC:                             829.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   9058.4039    378.240     23.949      0.000      8297.901  9818.907
# A            -11.0560     18.501     -0.598      0.553       -48.254    26.142
# ==============================================================================
# Omnibus:                        0.215   Durbin-Watson:                   2.518
# Prob(Omnibus):                  0.898   Jarque-Bera (JB):                0.133
# Skew:                          -0.118   Prob(JB):                        0.935
# Kurtosis:                       2.909   Cond. No.                         59.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### 5.4 Difference in rate of change in patients vs controls

# %%
# 2. Difference in the change of the hippocampus between patients and controls
# Our null hypothesis is that there is no difference

# Plot a scatter plot with Hippocampal volume vs. Age
ax = test_df.loc[(test_df.G==1)].plot(x='A',y='H',kind='scatter', color='Red')
test_df.loc[(test_df.G==2)].plot(x='A',y='H',kind='scatter', color='Green', ax=ax)

# Statistical test: H changes with A
res=smf.ols(formula="H ~ A + C(G) + A * C(G)",data=test_df).fit();
# print(res.f_pvalue);
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      H   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.056
# Method:                 Least Squares   F-statistic:                    0.1381
# Date:                Mon, 05 Dec 2016   Prob (F-statistic):              0.937
# Time:                        09:28:03   Log-Likelihood:                -410.96
# No. Observations:                  50   AIC:                             829.9
# Df Residuals:                      46   BIC:                             837.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept    9130.3140    514.527     17.745      0.000      8094.624  1.02e+04
# C(G)[T.2]    -172.2774    779.788     -0.221      0.826     -1741.908  1397.354
# A             -15.1721     24.801     -0.612      0.544       -65.093    34.749
# A:C(G)[T.2]     9.9169     38.291      0.259      0.797       -67.159    86.993
# ==============================================================================
# Omnibus:                        0.190   Durbin-Watson:                   2.517
# Prob(Omnibus):                  0.909   Jarque-Bera (JB):                0.100
# Skew:                          -0.102   Prob(JB):                        0.951
# Kurtosis:                       2.921   Cond. No.                         150.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # 6. Brain growth dynamics (from BrainBox)

# %%
# token (expires in 24h)
token = "lfupqrrc5k5zsemiw89rjqm94pfogvi"

# Get data from the Ferret Brain Project
prj_url="http://brainbox.pasteur.fr/project/json/nihpd2?token=lfupqrrc5k5zsemiw89rjqm94pfogvi"
res=url.urlopen(prj_url)
txt=res.read()
prj=json.loads(txt)
nfiles = len(prj['files']['list'])

# %%
N=nfiles

# %%
# Compute total segmented volume
vols = np.ndarray((N,))
subj = []
age = np.ndarray((N,))
sex = []

# Get individual mri annotations
for isub in range(0,N):
    bb_url="http://brainbox.pasteur.fr/mri/json?url="+prj['files']['list'][isub]+"&token="+token
    res=url.urlopen(bb_url)
    txt=res.read()
    mri=json.loads(txt)

    # Get SubjID, Age and Sex
    subj.append(str(mri['mri']['annotations']['nihpd2']['SubjectID']['data']))
    sex.append(str(mri['mri']['annotations']['nihpd2']['Sex']['data']))
    age[isub] = mri['mri']['annotations']['nihpd2']['Age']['data'];
    
    # Get voxel dimensions
    voxDim = float(mri['pixdim'][0]*mri['pixdim'][1]*mri['pixdim'][2])
    
    # Search for specific atlases within the annotations
    natlases = len(mri['mri']['atlas'])
    base = "http://brainbox.pasteur.fr"+mri['url']
    index = -1
    for i in range(0,natlases):
        if 'name' in mri['mri']['atlas'][i] and mri['mri']['atlas'][i]['name'] == 'ICV':
            index = i
            filename = mri['mri']['atlas'][i]['filename']
            print str(isub)+". [" + str(index) + "] " + base + filename
            break
    if index<0:
        continue

    # Load atlas
    atlas_url = base + filename
    # print atlas_url
    f=url.urlopen(atlas_url)
    local_file = open(filename, "wb")
    local_file.write(f.read())
    local_file.close()

    sum = 0
    try:
        img = nib.load(filename)
        dim = img.shape;
        # d = plotting.plot_img(img,cmap=plotting.cm.purple_green)
        data = np.reshape(img.get_data(),dim[0]*dim[1]*dim[2]);
        sum = np.sum(data>0)
    except:
        print "Unable to read"
        pass
    
    vols[isub]=sum*voxDim
# Out:
# 0. [1] http://brainbox.pasteur.fr/data/4b77d5559a07039b6bcb0599a597bd8b/5iup4ne5hk6nodb1wyy0la0pb9.nii.gz
# 1. [1] http://brainbox.pasteur.fr/data/eb8e858a27aec14b7a94aa365d2a6241/32xi9svov56xp3skka2vz8semi.nii.gz
# 2. [1] http://brainbox.pasteur.fr/data/023d70620b2918f89dbcab2041b1d424/xbhvhl7b8sv0zg87wdbo6r.nii.gz
# 3. [1] http://brainbox.pasteur.fr/data/b7336eb0610bb2ab263ae993b5107027/vhiqbsestktt0neadhvjthuxr.nii.gz
# 97. [1] http://brainbox.pasteur.fr/data/eccc6939fa5b31754abc7c2fc074219e/7ic8m5a90hsq0k9.nii.gz
# 98. [1] http://brainbox.pasteur.fr/data/b4a1a0f5dcc6af6dd1cfe6b1b26e2281/z1ba67ppeqaor.nii.gz
# 99. [1] http://brainbox.pasteur.fr/data/daaa343405b7242fea5921ea431238a3/88lilw6870ifi529.nii.gz
# 100. [1] http://brainbox.pasteur.fr/data/9ef2cf9dade18ecda72163bd0ec36522/ggajen23iks7zaor.nii.gz
# 101. [1] http://brainbox.pasteur.fr/data/301775ff9bec683d09b50aaddb51b663/27few9eo28olxr.nii.gz
# 102. [1] http://brainbox.pasteur.fr/data/6faaab3b97f14f5c35aac1a6767e78a8/zoxes297f3n89f6r.nii.gz
# 103. [1] http://brainbox.pasteur.fr/data/5a42ca9f07a00b35e3556c860b5afa27/y9o54av76869a4i.nii.gz
# 104. [1] http://brainbox.pasteur.fr/data/e84f3c7340a7526e637479903c236ca5/3uz2d81dfs9k9.nii.gz
# 105. [1] http://brainbox.pasteur.fr/data/bc17e1b1aa4466aafe38c5cab53295fc/i2bv5wc26c8wu3di.nii.gz
# 106. [1] http://brainbox.pasteur.fr/data/ce6ec2512765e215e00ed3a57b0d2fd1/7ulzzq8vn5mqjjor.nii.gz
# 107. [1] http://brainbox.pasteur.fr/data/e5100a5dc7bdfd8a11b22fb707271b55/tj5vowt7ali8uxr.nii.gz
# 108. [1] http://brainbox.pasteur.fr/data/79717213a3c0cc5b94a0461b0b6b3ea2/ki1lq0i7tffde7b9.nii.gz
# 109. [1] http://brainbox.pasteur.fr/data/87c1013728eba11a9f7a19cbdc407c42/ttyzbgwf1qph9f6r.nii.gz
# 110. [1] http://brainbox.pasteur.fr/data/fcf284b047afbfd3f0e668b4b8009a19/5kczt0qapn1att9.nii.gz
# 111. [1] http://brainbox.pasteur.fr/data/fe5faabec35b72373298a2490707fa8e/fehdlaype5h1if6r.nii.gz
# 112. [1] http://brainbox.pasteur.fr/data/2b54f166913477efaaf8a6e3c3eab374/0osq6xf5l33j714i.nii.gz
# 113. [1] http://brainbox.pasteur.fr/data/8710a3a50b64fe0f979aa919d5574a2c/mjtlv0209qftuik9.nii.gz

# %%
dyn_df=pd.DataFrame({'ICV':vols, 'SubjectID':subj, 'Age':age, 'Sex':sex});

# %%
sns.distplot(dyn_df.ICV)

# %%
sns.distplot(dyn_df.Age)

# %%
sns.lmplot('Age', 'ICV', hue='SubjectID', data=dyn_df, fit_reg=False)

# %%
dyn_df.to_csv("dyn.csv")

# %%
from scipy.optimize import minimize

# %%
def gompertzSurface(A,B,alpha,beta,v,t):
    """A Gompertz surface function"""
    sqErr = np.pow(v-A*np.exp(-B*np.exp(-t/(alpha+beta*A))),2)
    return sqErr;

# %%
x0 = np.array([1.3, 0.7, 0.8, 1.9, 1.2])
res = minimize(gompertzSurface, x0, method='nelder-mead',options={'xtol': 1e-8, 'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 339
#          Function evaluations: 571

# %%
print(res.x)
# Out:
# [ 1.  1.  1.  1.  1.]
