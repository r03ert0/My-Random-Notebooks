# %%
# %pylab inline
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.power as smp
import matplotlib.pyplot as plt
from scipy import linalg

from numpy.linalg import inv

# Install seaborn typing `conda install seaborn`
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x=np.array([[1,1.02],[1,1.06],[1,0.96],[1,0.92],[1,0.89]])

# %%
y=np.array([1.38,1.41,1.36,1.22,1.13])

# %%
b=(inv(x.T.dot(x))).dot((x.T.dot(y)))

# %%
b
# Out:
# array([-0.22923469,  1.57653061])

# %%
C=np.array([[3,2,1,1,0],[2,3,1,1,0],[1,1,3,2,0],[1,1,2,3,0],[0,0,0,0,3]])

# %%
C
# Out:
# array([[3, 2, 1, 1, 0],
#        [2, 3, 1, 1, 0],
#        [1, 1, 3, 2, 0],
#        [1, 1, 2, 3, 0],
#        [0, 0, 0, 0, 3]])

# %%
b=inv(x.T.dot(inv(C).dot(x))).dot(x.T).dot(inv(C).dot(y))

# %%
b
# Out:
# array([-0.2759995 ,  1.61590229])

# %%
plt.plot(x[:,1],y,'ro')

# %%
df = pd.DataFrame({'x':x[:,1],'y':y})

# %%
df
# Out:
#       x     y
# 0  1.02  1.38
# 1  1.06  1.41
# 2  0.96  1.36
# 3  0.92  1.22
# 4  0.89  1.13

# %%
sns.regplot(x="x", y="y", data=df);

# %%
r=linalg.lstsq(x[:,1], y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-562db4f6b536> in <module>()
# ----> 1 r=linalg.lstsq(x[:,1], y)
#
# //anaconda/lib/python2.7/site-packages/scipy/linalg/basic.pyc in lstsq(a, b, cond, overwrite_a, overwrite_b, check_finite, lapack_driver)
#     822     b1 = _asarray_validated(b, check_finite=check_finite)
#     823     if len(a1.shape) != 2:
# --> 824         raise ValueError('expected matrix')
#     825     m, n = a1.shape
#     826     if len(b1.shape) == 2:
#
# ValueError: expected matrix

# %%
x[:,1], y
# Out:
# (array([ 1.02,  1.06,  0.96,  0.92,  0.89]),
#  array([ 1.38,  1.41,  1.36,  1.22,  1.13]))
